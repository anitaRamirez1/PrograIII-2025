# %% [markdown]
# <a href="https://colab.research.google.com/github/anitaRamirez1/PrograIII-2025/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def resta(num1, num2):
  return num1 - num2

# %%
a = float(input ("nuum1 "))
b = float(input("num2 "))
respuesta1 = resta(a,b)
print("la resta es: ", respuesta1)
# Out:
# nuum1 5
# num2 2
# la resta es:  3.0
