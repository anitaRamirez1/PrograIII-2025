# %% [markdown]
# <a href="https://colab.research.google.com/github/anitaRamirez1/PrograIII-2025/blob/librerias/uso_librerias.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
ruta = "/content/notas.csv"
notas = pd.read_csv(ruta, sep=";", encoding="utf-8")

# %%
print(notas)
# Out:
#    alumno  notas
# 0    luis      5
# 1    juan      8
# 2   maria      9
# 3    jose     10
# 4   oscar      4
# 5   pedro      5
# 6  ramon       7
# 7  carmen      5

# %%
print( notas["alumno"][0] )
# Out:
# luis

# %%
#saca el listado de los alumnos aprobados
aprobados  = notas[ notas["notas"]>=6 ]
print(aprobados)
# Out:
#    alumno  notas
# 1    juan      8
# 2   maria      9
# 3    jose     10
# 6  ramon       7

# %%
#sacar el listado de los alumnos reprobados
reprobados = notas[ notas["notas"]<6 ]
print(reprobados)
# Out:
#    alumno  notas
# 0    luis      5
# 4   oscar      4
# 5   pedro      5
# 7  carmen      5

# %%
print("Cantidad de Alumnos aprobados", len(aprobados))

cantidad_aprobados = notas.loc[ notas["notas"]>=6 ].agg({"count"})
print(cantidad_aprobados)
# Out:
# Cantidad de Alumnos aprobados 4
#        alumno  notas
# count       4      4

# %%
grupo_notas = notas.groupby(["notas"]).agg({
    'alumno': lambda n: ', '.join( map(str,n) )
})
print(grupo_notas)
# Out:
#                     alumno
# notas
# 4                    oscar
# 5      luis, pedro, carmen
# 7                   ramon
# 8                     juan
# 9                    maria
# 10                    jose

# %%
ruta_años = "/content/añosEdad.csv"
añosEdad = a(ruta_años, sep=";")
print(añosEdad.columns)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3790185016.py in <cell line: 0>()
#       1 ruta_años = "/content/añosEdad.csv"
# ----> 2 añosEdad = a(ruta_años, sep=";")
#       3 print(añosEdad.columns)
#
# NameError: name 'a' is not defined

# %%
#sacar el listado de los alumnos mayores
mayores = añosEdad[ añosEdad["años de edad"]>18 ]
print(mayores)
# Out:
#    años de edad  alumno
# 2            30   maria
# 3            20    jose
# 4            22   oscar
# 5            20   pedro
# 6            23  ramon
# 7            21  carmen

# %%
#sacar el listado de los alumnos mayores
menores = añosEdad[ añosEdad["años de edad"]<18 ]
print(menores)
# Out:
#    años de edad alumno
# 1            17   juan

# %%
print("Cantidad de Alumnos mayores de edad", len(mayores))

cantidad_aprobados = notas.loc[ notas["notas"]>=6 ].agg({"count"})
print(cantidad_aprobados)

# %%
import pandas as pd
ruta = "/content/añosEdad.csv"
edades= pd.read_csv(ruta,sep=";",encoding="UTF-8")


edades['grupo_edad'] = edades['años de edad'].apply(lambda x: 'Menor de edad' if x < 18 else 'Mayor de edad')


conteo = edades['grupo_edad'].value_counts()

sns.set(style="whitegrid")
sns.countplot(
    data=edades,
    x='grupo_edad',
    hue='grupo_edad',
    palette={'Menor de edad': 'Blue', 'Mayor de edad': 'RED'},
    legend=False
)
plt.title('Distribución de alumnos menores y mayores de edad')
plt.xlabel('Grupo de edad')
plt.ylabel('Cantidad de alumnos')
plt.show()

# %%
import tensorflow as tf
import pandas as pd
import numpy as np

# %%
grados = pd.read_csv("/content/grados.csv", sep=";", encoding="utf-8")
print(grados, grados["f"])
# Out:
#      c      f
# 0  -50  -58.0
# 1  -40  -40.0
# 2  -30  -22.0
# 3  -20   -4.0
# 4  -10   14.0
# 5   -9   15.8
# 6   -8   17.6
# 7   -7   19.4
# 8   -6   21.2
# 9   -5   23.0
# 10  -4   24.8
# 11  -3   26.6
# 12  -2   28.4
# 13  -1   30.2
# 14   0   32.0
# 15   1   33.8
# 16   2   35.6
# 17   3   37.4
# 18   4   39.2
# 19   5   41.0
# 20   6   42.8
# 21   7   44.6
# 22   8   46.4
# 23   9   48.2
# 24  10   50.0
# 25  20   68.0
# 26  30   86.0
# 27  40  104.0
# 28  50  122.0 0     -58.0
# 1     -40.0
# 2     -22.0
# 3      -4.0
# 4      14.0
# 5      15.8
# 6      17.6
# 7      19.4
# 8      21.2
# 9      23.0
# 10     24.8
# 11     26.6
# 12     28.4
# 13     30.2
# 14     32.0
# 15     33.8
# 16     35.6
# 17     37.4
# 18     39.2
# 19     41.0
# 20     42.8
# 21     44.6
# 22     46.4
# 23     48.2
# 24     50.0
# 25     68.0
# 26     86.0
# 27    104.0
# 28    122.0
# Name: f, dtype: float64

# %%
c=grados["c"]
f=grados["f"]
print(c,f)
# Out:
# 0    -50
# 1    -40
# 2    -30
# 3    -20
# 4    -10
# 5     -9
# 6     -8
# 7     -7
# 8     -6
# 9     -5
# 10    -4
# 11    -3
# 12    -2
# 13    -1
# 14     0
# 15     1
# 16     2
# 17     3
# 18     4
# 19     5
# 20     6
# 21     7
# 22     8
# 23     9
# 24    10
# 25    20
# 26    30
# 27    40
# 28    50
# Name: c, dtype: int64 0     -58.0
# 1     -40.0
# 2     -22.0
# 3      -4.0
# 4      14.0
# 5      15.8
# 6      17.6
# 7      19.4
# 8      21.2
# 9      23.0
# 10     24.8
# 11     26.6
# 12     28.4
# 13     30.2
# 14     32.0
# 15     33.8
# 16     35.6
# 17     37.4
# 18     39.2
# 19     41.0
# 20     42.8
# 21     44.6
# 22     46.4
# 23     48.2
# 24     50.0
# 25     68.0
# 26     86.0
# 27    104.0
# 28    122.0
# Name: f, dtype: float64

# %%
#modelo
modelo = tf.keras.Sequential()
modelo.add(tf.keras.layers.Dense(units=1, input_shape=[1]))
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
#copilar el modelo

modelo.compile(
    optimizer=tf.keras.optimizers.Adam(0.1),
    loss='mean_squared_error'
)

# %%
#entrenar el modelo
epocas = modelo.fit(c, f, epochs=200, verbose=1)
# Out:
# Epoch 1/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 467ms/step - loss: 2679.2412
# Epoch 2/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 2514.3135
# Epoch 3/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 2357.6255
# Epoch 4/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 2209.3032
# Epoch 5/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 2069.4534
# Epoch 6/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 1938.1487
# Epoch 7/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 1815.4332
# Epoch 8/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 1701.3152
# Epoch 9/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 1595.7648
# Epoch 10/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 1498.7119
# Epoch 11/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 1410.0419
# Epoch 12/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 1329.5955
# Epoch 13/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 1257.1655
# Epoch 14/200
# ...

# %%
#prediccion
g = int(input("celcius: "))
resp = modelo.predict(np.array([g]))
print("farenheit: ", resp)
# Out:
# celcius: 30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# farenheit:  [[71.084]]
