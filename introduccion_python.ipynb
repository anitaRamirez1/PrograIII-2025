# %% [markdown]
# <a href="https://colab.research.google.com/github/anitaRamirez1/PrograIII-2025/blob/main/introduccion_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hola mundo")
print("bienvenidos chicos a progrmacin computacional III")
# Out:
# hola mundo
# bienvenidos chicos a progrmacin computacional III

# %%
nombre = "Anita Ramirez"
edad = 18
print("hola", nombre, edad)
edad = "quince"
print("tu edad es: ", edad)
# Out:
# hola Anita Ramirez 18
# tu edad es:  quince

# %%
num1 = 5
num2 = 5.5
suma = num1 + num2
print("la suma es: ", suma)
# Out:
# la suma es:  10.5

# %%
num1 = float(input("num1: "))
num2 = float(input("num2: "))
suma = num1 + num2
print("la suma es: ", suma)
# Out:
# num1: 5
# num2: 5
# la suma es:  10.0

# %%
num1 = float(input("num1: "))
num2 = float(input("num2: "))
resta = num1 - num2
print("la resta es: ", resta)
# Out:
# num1: 5
# num2: 5
# la resta es:  0.0

# %%
def resta(num1, num2):
  return num1 - num2

# %%
a = float(input ("nuum1 "))
b = float(input("num2 "))
respuesta1 = resta(a,b)
print("la resta es: ", respuesta1)
# Out:
# nuum1 5
# num2 3
# la resta es:  2.0

# %%
#de celcius a farenhei
def celciusFarerenheit(c):
  return c*1.8 + 32

# %%
c = int(input("grados c: "))
f =celciusFarerenheit(c)
print("f : ", f)
# Out:
# grados c: 38
# f :  100.4

# %%
#de  farenhei a celcius

def FarerenheitCelcius(F):
  return (F - 32)* 0.555556
F = int(input("grados c: "))
c =FarerenheitCelcius(F)
print("c : ", c)

# %%
#de  farenhei a celcius y viceversa

def FarerenheitCelcius(F):
  return (F - 32)* 5/9
F = float(input("grados f: "))
c =FarerenheitCelcius(F)
print("c : ", c)


f =celciusFarerenheit(c)
print("f : ", f)
# Out:
# grados f: 100.4
# f :  38.00003040000001
# c :  100.40005472000001

# %%
def FarerenheitCelcius(F):
  return (F - 32)* 5/9


F = float(input("grados f: "))
c =FarerenheitCelcius(F)
print("c : ", c)
# Out:
# grados f: 100.4
# c :  38.0

# %%
#grados celcius a kelin
def CelciusKelvin(c):
 return c +273.15
c = float(input("grados c: "))
k = CelciusKelvin(c)

print("k: ", k)
# Out:
# grados c: 35
# k:  308.15

# %%
#calcular el sueldo de un empleado segun el numero de horas trabajadas yel valor por horas


def sueldo(numHrs, valorXhrs):
  sueldo = numHrs*valorXhrs * 30

  return sueldo

# %%
numHrs = float(input(" Hrs: "))
valorXhrs = float(input(" valor Hrs: "))
sueldo = sueldo(numHrs, valorXhrs)
print("sueldo: ", sueldo)
# Out:
#  Hrs: 8
#  valor Hrs: 10
# sueldo:  2400.0

# %%
#que permita elevar un numero a un exponente

def exponenciacion(b,e):
  return b**e


b = float(input("base "))
e = float(input("expnente "))
resultado = exponenciacion(b,e)
print("el numero ", b, "elevado a ", e, "el resultado es: ", resultado)
# Out:
# base 8
# expnente 3
# el numero  8.0 elevado a  3.0 el resultado es:  512.0

# %%
a = float(input("num1 "))
b = float(input("num2 "))

sum = lambda a,b: a+b
print ("la suma de",a, "mas ", b, "es igual, ",sum(a,b))
# Out:
# num1 5
# num2 2
# la suma de 5.0 mas  2.0 es igual,  7.0

# %%
numeros = [2,4,6,8,7,9]
potencia = int(input("potencia: "))
numeropotencia = map(lambda num: num**potencia, numeros)

print(list(numeropotencia))
# Out:
# potencia: 2
# [4, 16, 36, 64, 49, 81]

# %%
ntablas = int(input("tabla: "))
numeros = [1,2,3,4,5,6,7,8,9]
tabla = map(lambda num: num*ntablas, numeros)

print(list(tabla))
# Out:
# tabla: 3
# [3, 6, 9, 12, 15, 18, 21, 24, 27]

# %%
serie = [5,6,9,2,7,8]
pares = filter(lambda num: num%2 ==0,serie)
print(list(pares))


impares = filter(lambda num: num%2!=0, serie)
print(list(impares))
# Out:
# [6, 2, 8]
# [5, 9, 7]

# %%
serieUser= input("serie: ")
serieUser = serieUser.split(",")
pares = filter(lambda num: int(num)%2==0, serieUser)

print(list(pares))
# Out:
# serie: 1,5,2,9,1
# ['2']

# %%
serieUser= input("notas: ")
serieUser = serieUser.split(",")
aprovados = filter(lambda num: float(num)>5, serieUser)

print(list(aprovados))
# Out:
# notas: 2,5,6.1,6,8
# ['6.1', '6', '8']

# %%
entrada = input("Introduce las notas separadas por comas (ej. 5,7.5,8,4,6): ")


notas = list(map(float, entrada.split(",")))
aprobados = list(filter(lambda nota: nota >= 6, notas))


reprobados = list(filter(lambda nota: nota < 6, notas))

print(f"\nTotal de notas ingresadas: {len(notas)}")
print(f"Aprobados (>=6): {len(aprobados)} -> {aprobados}")
print(f"Reprobados (<6): {len(reprobados)} -> {reprobados}")
# Out:
# Introduce las notas separadas por comas (ej. 5,7.5,8,4,6): 5,2,9,4,10,6.1
#
# Total de notas ingresadas: 6
# Aprobados (>=6): 3 -> [9.0, 10.0, 6.1]
# Reprobados (<6): 3 -> [5.0, 2.0, 4.0]

# %% [markdown]
# TUPLAS

# %%
tupla = (5,2,3,7,8,9)
#tupla [0]= 1
print("tupla: ", tupla,"primer elemento", tupla[0], "el numero 5 aparece ",tupla.count(5))
print ("el ultimo numero ", tupla[-1])
print ("rango: ", tupla[0:5])
# Out:
# tupla:  (5, 2, 3, 7, 8, 9) primer elemento 5 el numro 5 aparece  1
# el ultimo numero  9
# rango:  (5, 2, 3, 7, 8)

# %%
import datetime
fecha = datetime.date.today()
semana = ("Domingo", "Lunes", "Martes", "Miercoles", "Jueves", "Viernes", "Sabado")
mes = ("","Enero", "Febrero", "Marzo", "Abril", "Mayo", "Junio", "Julio", "Agosto", "Septiembre", "Octubre", "Noviembre", "Diciembre")
dia = fecha.day
mes = fecha.month
year = fecha.year
diaSemana = semana[fecha.isoweekday()]

print(diaSemana, dia, "del", meses [mes], "del", year)
print(fecha, fecha.isoweekday(), diaSemana)
print(dia, mes, year)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2573189238.py in <cell line: 0>()
#       8 diaSemana = semana[fecha.isoweekday()]
#       9
# ---> 10 print(diaSemana, dia, "del", meses [mes], "del", year)
#      11 print(fecha, fecha.isoweekday(), diaSemana)
#      12 print(dia, mes, year)
#
# NameError: name 'meses' is not defined

# %%
lista = [5,9,8,4, "progra III", True, [4,8,9,[8,9,4]]]
print(lista)
# Out:
# [5, 9, 8, 4, 'progra III', True, [4, 8, 9, [8, 9, 4]]]

# %%
def calcularPromedio(nota, notas):
  return notas[1]*0.3 + nota

# %%
from functools import reduce

notas =[["lab1 "], 8], [["lab2 "], 9], [["parcial "], 10]
prom = reduce(calcularPromedio, notas, 0)
print ("nota final: ", prom)
# Out:
# nota final:  8.1
